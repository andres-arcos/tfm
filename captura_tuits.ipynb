# %%
from librerias import *
from variables_globales import *
from funciones import *

# %% [markdown]
# ### Captura tuits Daniel Noboa

# %%
query = '("Daniel Noboa" OR @DanielNoboaOk) lang:es -is:retweet'
tweets, unicos = fetch_all_tweets(
    query=query,
    headers=headers,
    max_total=6000,
    max_results=100,
    carpeta="Daniel Noboa",
    fecha_dia="2025-07-21"
)
# Out:
# Límite total: 60
# Solicitudes restantes: 55
# Se reinicia en: 1753625382
# unicos.. 100
# Tweets recolectados: 100
# Límite total: 60
# Solicitudes restantes: 54
# Se reinicia en: 1753625382
# unicos.. 200
# Tweets recolectados: 200
# Límite total: 60
# Solicitudes restantes: 53
# Se reinicia en: 1753625382
# unicos.. 293
# Tweets recolectados: 293
# Límite total: 60
# Solicitudes restantes: 52
# Se reinicia en: 1753625382
# unicos.. 389
# Tweets recolectados: 389
# Límite total: 60
# Solicitudes restantes: 51
# Se reinicia en: 1753625382
# unicos.. 487
# Tweets recolectados: 487
# Límite total: 60
# Solicitudes restantes: 50
# Se reinicia en: 1753625382
# unicos.. 587
# Tweets recolectados: 587
# Límite total: 60
# Solicitudes restantes: 49
# Se reinicia en: 1753625382
# unicos.. 686
# Tweets recolectados: 686
# Límite total: 60
# Solicitudes restantes: 48
# Se reinicia en: 1753625382
# unicos.. 786
# Tweets recolectados: 786
# Límite total: 60
# Solicitudes restantes: 47
# ...

# %% [markdown]
# ### Captura tuits Luisa Gonzáles

# %%
query = '("Luisa González" OR "Luisa Gonzalez" OR @LuisaGonzalezEc) lang:es -is:retweet'
tweets, unicos = fetch_all_tweets(
    headers=headers,
    query=query,
    max_total=6000,         # Total deseado
    max_results=100,        # Máximo permitido por solicitud
    carpeta="Luisa Gonzales",  # Carpeta destino
    fecha_dia="2025-07-21"
)
fetch_all_tweets
# Out:
# Límite total: 60
# Solicitudes restantes: 59
# Se reinicia en: 1753626584
# unicos.. 100
# Tweets recolectados: 100
# Límite total: 60
# Solicitudes restantes: 58
# Se reinicia en: 1753626584
# unicos.. 200
# Tweets recolectados: 200
# Límite total: 60
# Solicitudes restantes: 57
# Se reinicia en: 1753626584
# unicos.. 300
# Tweets recolectados: 300
# Límite total: 60
# Solicitudes restantes: 56
# Se reinicia en: 1753626584
# unicos.. 400
# Tweets recolectados: 400
# Límite total: 60
# Solicitudes restantes: 55
# Se reinicia en: 1753626584
# unicos.. 500
# Tweets recolectados: 500
# Límite total: 60
# Solicitudes restantes: 54
# Se reinicia en: 1753626584
# unicos.. 599
# Tweets recolectados: 599
# Límite total: 60
# Solicitudes restantes: 53
# Se reinicia en: 1753626584
# unicos.. 699
# Tweets recolectados: 699
# Límite total: 60
# Solicitudes restantes: 52
# Se reinicia en: 1753626584
# unicos.. 799
# Tweets recolectados: 799
# Límite total: 60
# Solicitudes restantes: 51
# ...
